# %% [markdown]
# Use the Data Library in a Notebook

# %%
import lseg.data as ld
import pandas as pd

# %%
# Open a session
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x22be4b2f620 {name='workspace'}>

# %%
# Example: Get data
df = ld.get_data(
    universe=['AAPL.O', 'MSFT.O', 'GOOGL.O'],
    fields=['TR.PriceClose', 'TR.Volume']
)

print(df)
# Out:
#   Instrument  Price Close    Volume
# 0     AAPL.O       273.68  34376898
# 1     MSFT.O       413.27  44857850
# 2    GOOGL.O       318.58  39170012

# %%
# Close the session
ld.close_session()
